# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# EDA

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
#checking for NAN values

# %%
df.replace(-1, np.NaN,inplace=True)

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
sns.distplot(x=df['satisfaction_level'])
# Out:
# <ipython-input-11-b8668df5cfc0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['satisfaction_level'])
# <Axes: ylabel='Density'>

# %%
#most of the employees tends to have good satisfaction level and data is well distributed

# %%
sns.boxplot(x=df['satisfaction_level'])
# Out:
# <Axes: xlabel='satisfaction_level'>

# %%
#ensures no outliers

# %%
sns.scatterplot(x=df['satisfaction_level'],y=df['average_montly_hours'],hue=df['left'])
# Out:
# <Axes: xlabel='satisfaction_level', ylabel='average_montly_hours'>

# %%
#it shows that some employee lefts because they gets less hours which shows their satisfactory level as well
#on the other hand some employee even left because of more active hours and quite interestingly they left even having high satisfactory level

# %%
sns.countplot(x='number_project',data=df[df['satisfaction_level']<0.1])
# Out:
# <Axes: xlabel='number_project', ylabel='count'>

# %%
#employees with <0.1 satisfaction_level engaged with high no. of project which might be the reason for their later exits.

# %%
sns.boxplot(df['last_evaluation'])
# Out:
# <Axes: >

# %%
#clean, no outliers

# %%
sns.distplot(x=df['last_evaluation'])
# Out:
# <ipython-input-21-9b987d367706>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['last_evaluation'])
# <Axes: ylabel='Density'>

# %%
#data is centered distributed

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
sns.boxplot(df['number_project'])
# Out:
# <Axes: >

# %%
sns.countplot(x=df['number_project'])
# Out:
# <Axes: xlabel='number_project', ylabel='count'>

# %%
#majority having 3-4 projects

# %%
sns.scatterplot(x=df['number_project'],y=df['average_montly_hours'])
# Out:
# <Axes: xlabel='number_project', ylabel='average_montly_hours'>

# %%
#having 7 projects meaning high avg monthly hours

# %%
df['average_montly_hours'].mean()
# Out:
# 201.0503366891126

# %%
sns.distplot(df['average_montly_hours'])
# Out:
# <ipython-input-30-27b4707b93c7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['average_montly_hours'])
# <Axes: xlabel='average_montly_hours', ylabel='Density'>

# %%
plt.figure(figsize=(10,3))
sns.countplot(x='Work_accident',data=df[df['average_montly_hours']>200])
plt.show()

# %%
#employee work accdient cases with 200+ avg monthly work hours is pretty less

# %%
sns.boxplot(df['time_spend_company'])
# Out:
# <Axes: >

# %%
#outliers present. Needs to be treated. Using imputation method.

# %%
q1=df['time_spend_company'].quantile(0.25)
q3=df['time_spend_company'].quantile(0.75)

iqr=q3-q1

upper=q3+1.5*iqr
lower=q1-1.5*iqr
upper,lower
# Out:
# (5.5, 1.5)

# %%
def out(x):
  if x>upper:
    return upper
  elif x<lower:
    return lower
  else:
    return x
df['time_spend_company']=df['time_spend_company'].apply(out)

# %%
sns.boxplot(df['time_spend_company'])
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Department'],y=df['time_spend_company'])
plt.xticks(rotation=90)
plt.show()

# %%
#management employees tend to stay a bit longer than others

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                 3.0              0     1                      0      sales
# 1                 5.5              0     1                      0      sales
# 2                 4.0              0     1                      0      sales
# 3                 5.0              0     1                      0      sales
# 4                 3.0              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df['Work_accident'].value_counts()
# Out:
# 0    12830
# 1     2169
# Name: Work_accident, dtype: int64

# %%
np.corrcoef(df['Work_accident'], df['left'])
# Out:
# array([[ 1.        , -0.15462163],
#        [-0.15462163,  1.        ]])

# %%
#bad correlation between work accident and left

# %%
sns.countplot(x='left',data=df)
# Out:
# <Axes: xlabel='left', ylabel='count'>

# %%
#almost 1/3rd of the employee left

# %%
sns.heatmap(df.corr()[['left']],annot=True)
# Out:
# <ipython-input-46-428f2aec8b41>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr()[['left']],annot=True)
# <Axes: >

# %%
sns.barplot(x=df["promotion_last_5years"], y=df["average_montly_hours"], hue=df["left"])
# Out:
# <Axes: xlabel='promotion_last_5years', ylabel='average_montly_hours'>

# %%
#employees not getting promoted even after high working hours, leaving company whearas those getting promoted, remains with company even
#after high working hours

# %%
#converting salary from object to float

def sal_int(x):
  if x == 'low':
    return 0
  elif x == 'medium':
    return 1
  elif x == 'high':
    return 2
df['salary']=df['salary'].apply(sal_int)

# %%
df['salary']=df['salary'].astype(int)

# %%
df['salary'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14999 entries, 0 to 14998
# Series name: salary
# Non-Null Count  Dtype
# --------------  -----
# 14999 non-null  int64
# dtypes: int64(1)
# memory usage: 117.3 KB

# %%
sns.countplot(x='salary',data=df[df['left']==1])
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %%
#low salary leading to leaving company

# %% [markdown]
# MODEL BUILDING

# %%
x=df.drop(columns='left')
y=df['left']
x
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                 3.0              0
# 1                       262                 5.5              0
# 2                       272                 4.0              0
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
X_train,X_test,y_train,y_test = train_test_split(x, y, test_size=0.20, random_state=4)

# %%
X_train.shape,X_test.shape
# Out:
# ((11999, 9), (3000, 9))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11999 entries, 2205 to 1146
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11999 non-null  float64
#  1   last_evaluation        11999 non-null  float64
#  2   number_project         11999 non-null  int64
#  3   average_montly_hours   11999 non-null  int64
#  4   time_spend_company     11999 non-null  float64
#  5   Work_accident          11999 non-null  int64
#  6   promotion_last_5years  11999 non-null  int64
#  7   Department             11999 non-null  object
#  8   salary                 11999 non-null  int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 937.4+ KB

# %%
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse=False, drop='first'),[7])],remainder='passthrough')

step2=LogisticRegression(max_iter=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
pred=pipe.predict(X_test)

print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# [[2086  201]
#  [ 427  286]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      2287
#            1       0.59      0.40      0.48       713
#
#     accuracy                           0.79      3000
#    macro avg       0.71      0.66      0.67      3000
# weighted avg       0.77      0.79      0.78      3000

# %%
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse=False, drop='first'),[7])],remainder='passthrough')

step2 = KNeighborsClassifier(n_neighbors=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
pred=pipe.predict(X_test)

print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# [[2172  115]
#  [  62  651]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      2287
#            1       0.85      0.91      0.88       713
#
#     accuracy                           0.94      3000
#    macro avg       0.91      0.93      0.92      3000
# weighted avg       0.94      0.94      0.94      3000

# %%
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse=False, drop='first'),[7])],remainder='passthrough')

step2 = SVC(kernel='rbf',C=10000)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
pred=pipe.predict(X_test)

print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# [[2194   93]
#  [  80  633]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      2287
#            1       0.87      0.89      0.88       713
#
#     accuracy                           0.94      3000
#    macro avg       0.92      0.92      0.92      3000
# weighted avg       0.94      0.94      0.94      3000

# %%
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse=False, drop='first'),[7])],remainder='passthrough')

step2 =DecisionTreeClassifier(class_weight= 'balanced', criterion= 'gini', max_depth= 8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
pred=pipe.predict(X_test)

print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[2248   39]
#  [  42  671]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2287
#            1       0.95      0.94      0.94       713
#
#     accuracy                           0.97      3000
#    macro avg       0.96      0.96      0.96      3000
# weighted avg       0.97      0.97      0.97      3000
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse=False, drop='first'),[7])],remainder='passthrough')

step2 = RandomForestClassifier(n_estimators=150,
                              random_state=3,
                              max_samples=0.3,
                              max_features=0.35,
                              max_depth=15,
                            bootstrap=True)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
pred=pipe.predict(X_test)

print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# [[2280    7]
#  [  50  663]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2287
#            1       0.99      0.93      0.96       713
#
#     accuracy                           0.98      3000
#    macro avg       0.98      0.96      0.97      3000
# weighted avg       0.98      0.98      0.98      3000

# %%
import pickle

pickle.dump(df,open('df5.pkl','wb'))
pickle.dump(pipe,open('pipe5.pkl','wb'))

# %%
X_train
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2205                 0.70             0.69               3
# 11396                0.63             0.48               4
# 7877                 0.43             0.46               2
# 2634                 0.44             0.42               4
# 8807                 0.49             0.68               3
# ...                   ...              ...             ...
# 6017                 0.82             0.59               3
# 709                  0.42             0.48               2
# 10679                0.63             0.55               4
# 8366                 0.63             0.84               4
# 1146                 0.80             0.95               5
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 2205                    102                 4.0              1
# 11396                   180                 4.0              0
# 7877                    239                 3.0              1
# ...
